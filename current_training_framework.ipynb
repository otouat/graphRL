# %% [markdown]
# ## GRAN Test

# %%
import os
import sys
import torch
import logging
import traceback
import numpy as np
from pprint import pprint

from train_runners import *
from utils.logger import setup_logging
from utils.arg_helper import parse_arguments, get_config

torch.set_printoptions(profile='full')

# %%
config = get_config("config/graphrnn_rnn_erdos.yaml")
np.random.seed(config.seed)
torch.manual_seed(config.seed)
torch.cuda.manual_seed_all(config.seed)
config.use_gpu = config.use_gpu and torch.cuda.is_available()
torch.cuda.empty_cache()
# log info
log_file = os.path.join(config.save_dir, "log_exp_{}.txt".format(config.run_id))
logger = setup_logging("info", log_file)
logger.info("Writing log file to {}".format(log_file))
logger.info("Exp instance id = {}".format(config.run_id))
#logger.info("Exp comment = {}".format(args.comment))
logger.info("Config =")
print(">" * 80)
pprint(config)
print("<" * 80)

# Run the experiment
try:
    runner = eval(config.runner)(config)
    runner.train()
    #runner.test()
except:
    logger.error(traceback.format_exc())

sys.exit(0)
# Out:
# C:\Users\Ousmane\PycharmProjects\graphRL\utils\arg_helper.py:39: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   config = edict(yaml.load(open(config_file, 'r')))
# INFO  | 2021-07-04 20:09:53,567 | <ipython-input-2-181e172b7e17> | line 10   : Writing log file to exp/GraphRNN\RNN_erdos_2021-Jul-04-20-09-53_12812\log_exp_12812.txt
# INFO  | 2021-07-04 20:09:53,568 | <ipython-input-2-181e172b7e17> | line 11   : Exp instance id = 12812
# INFO  | 2021-07-04 20:09:53,569 | <ipython-input-2-181e172b7e17> | line 13   : Config =
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# {'dataset': {'data_path': 'data',
#              'dev_ratio': 0.2,
#              'has_node_feat': False,
#              'is_overwrite_precompute': False,
#              'is_sample_subgraph': True,
#              'is_save_split': False,
#              'loader_name': 'GRANData',
#              'name': 'erdos',
#              'node_order': 'BFS',
#              'num_fwd_pass': 1,
#              'num_subgraph_batch': 50,
#              'train_ratio': 0.8},
#  'device': 'cuda:0',
#  'exp_dir': 'exp/GraphRNN',
#  'exp_name': 'RNN_erdos_2021-Jul-04-20-09-53_12812',
#  'gpus': [0],
#  'model': {'batch_ratio': 32,
#            'batch_size': 32,
#            'embedding_size_output': 64,
#            'embedding_size_rnn': 64,
#            'embedding_size_rnn_output': 8,
#            'hidden_size_rnn': 128,
#            'hidden_size_rnn_output': 16,
#            'is_mlp': False,
#            'max_num_node': 200,
#            'max_prev_node': 180,
#            'name': 'RNN',
#            'num_layers': 4,
#            'test_batch_size': 32,
#            'test_total_size': 1000},
#  'run_id': '12812',
#  'runner': 'GraphRnnRunner',
#  'save_dir': 'exp/GraphRNN\\RNN_erdos_2021-Jul-04-20-09-53_12812',
#  'seed': 1234,
#  'test': {'batch_size': 20,
#           'better_vis': True,
#           'is_single_plot': True,
#           'is_test_ER': False,
#           'is_vis': True,
#           'num_test_gen': 20,
#           'num_vis': 20,
#           'num_workers': 4,
#           'test_model_dir': 'exp/GraphRNN/RNN_erdos_2021-Jun-19-15-49-41_8428/',
#           'test_output_name': 'output_snapshot_0000100.pth',
#           'test_rnn_name': 'rnn_snapshot_0000100.pth',
#           'vis_num_row': 5},
#  'train': {'batch_size': 1,
#            'display_iter': 10,
#            'is_resume': False,
#            'lr': 0.001,
#            'lr_decay': 0.3,
#            'lr_decay_epoch': [400, 1000],
#            'max_epoch': 1000,
#            'momentum': 0.9,
#            'num_workers': 0,
#            'optimizer': 'Adam',
#            'resume_dir': None,
#            'resume_epoch': 5000,
#            'resume_model': 'model_snapshot_0005000.pth',
#            'shuffle': True,
#            'snapshot_epoch': 100,
#            'valid_epoch': 50,
#            'wd': 0.0},
#  'use_gpu': True,
#  'use_horovod': False}
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# INFO  | 2021-07-04 20:09:53,893 | train_runners.py          | line 450  : Train/val/test = 80/20/20
# INFO  | 2021-07-04 20:09:53,898 | train_runners.py          | line 463  : No Edges vs. Edges in training set = 19.099272421116122
# max # nodes = 199 || mean # nodes = 149.5
# max # edges = 1987 || mean # edges = 1152.85
# C:\Users\Ousmane\PycharmProjects\graphRL\baselineModels\GraphRNN\model.py:45: UserWarning: nn.init.constant is now deprecated in favor of nn.init.constant_.
#   nn.init.constant(param, 0.25)
# INFO  | 2021-07-04 20:11:14,781 | train_runners.py          | line 573  : NLL Loss @ epoch 0001 iteration 00000032 = 0.23165538907051086
# INFO  | 2021-07-04 20:11:27,638 | train_runners.py          | line 573  : NLL Loss @ epoch 0002 iteration 00000064 = 0.13310933113098145
# INFO  | 2021-07-04 20:11:41,265 | train_runners.py          | line 573  : NLL Loss @ epoch 0003 iteration 00000096 = 0.13208067417144775
# ERROR | 2021-07-04 20:11:49,641 | <ipython-input-2-181e172b7e17> | line 24   : Traceback (most recent call last):
#   File "<ipython-input-2-181e172b7e17>", line 21, in <module>
#     runner.train()
#   File "C:\Users\Ousmane\PycharmProjects\graphRL\train_runners.py", line 566, in train
#     scheduler_rnn, scheduler_output, self.config.model.num_layers)
#   File "C:\Users\Ousmane\PycharmProjects\graphRL\baselineModels\GraphRNN\train.py", line 247, in train_rnn_epoch_runner
#     train_loss.backward()
#   File "D:\anaconda3\envs\graphRL\lib\site-packages\torch\tensor.py", line 245, in backward
#     torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#   File "D:\anaconda3\envs\graphRL\lib\site-packages\torch\autograd\__init__.py", line 147, in backward
#     allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
# KeyboardInterrupt
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# D:\anaconda3\envs\graphRL\lib\site-packages\IPython\core\interactiveshell.py:3445: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
torch.cuda.empty_cache()
