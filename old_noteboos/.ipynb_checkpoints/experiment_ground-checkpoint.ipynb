# %% [markdown]
# ## Experimentation ground

# %% [markdown]
# ### Imports

# %%
import pickle
from random import shuffle
import random

from networkx.algorithms.community import LFR_benchmark_graph

from baselineModels.GraphRNN.data import Graph_to_sequence
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import networkx as nx
import torch
from torch.utils.data import Dataset

# %% [markdown]
# ### Training loss visualisation

# %%
def vis_train_loss_epoch(folder_name, title):
    train_data_file = open(folder_name, 'rb')
    db = pickle.load(train_data_file)
    epoch = list(range(len(db['train_step'])))
    plt.plot(epoch, db['train_loss'])
    plt.title(title)
    plt.xlabel("Epoch")
    plt.ylabel("Train_loss")
    plt.show()

# %%
folder_rnn = 'exp/GraphRNN/rnn/community2/RNN_community2_2021-Aug-15-11-06-04_18756/train_stats.p'

vis_train_loss_epoch(folder_rnn, 'graph_rnn_rnn')
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# <ipython-input-4-abdd58c50b5e> in <module>
#       1 folder_rnn = 'exp/GraphRNN/rnn/community2/RNN_community2_2021-Aug-15-11-06-04_18756/train_stats.p'
#       2
# ----> 3 vis_train_loss_epoch(folder_rnn, 'graph_rnn_rnn')
#       4
#       5
#
# <ipython-input-2-e36321eeccf7> in vis_train_loss_epoch(folder_name, title)
#       1 def vis_train_loss_epoch(folder_name, title):
#       2     train_data_file = open(folder_name, 'rb')
# ----> 3     db = pickle.load(train_data_file)
#       4     epoch = list(range(len(db['train_step'])))
#       5     plt.plot(epoch, db['train_loss'])
#
# EOFError: Ran out of input

# %%
folder_mlp_1000='exp/GraphRNN/RNN_erdos_2021-Jun-30-13-19-51_9376/train_stats.p'
vis_train_loss_epoch(folder_mlp_1000, 'graph_rnn_mlp_1000')

# %% [markdown]
# ### Experiment on the influence of synthethic dataset

# %%
def calc_max_prev_node(G, iter=20000, topk=10):
    max_prev_node = []
    for i in range(iter):
        if i % (iter / 5) == 0:
            print('iter {} times'.format(i))
        adj_idx = np.random.randint(len(G))
        adj_copy = G[adj_idx].copy()
        # print('Graph size', adj_copy.shape[0])
        x_idx = np.random.permutation(adj_copy.shape[0])
        adj_copy = adj_copy[np.ix_(x_idx, x_idx)]
        adj_copy_matrix = np.asmatrix(adj_copy)
        G = nx.from_numpy_matrix(adj_copy_matrix)
        # then do bfs in the permuted G
        start_idx = np.random.randint(adj_copy.shape[0])
        x_idx = np.array(bfs_seq(G, start_idx))
        adj_copy = adj_copy[np.ix_(x_idx, x_idx)]
        # encode adj
        adj_encoded = encode_adj_flexible(adj_copy.copy())
        if adj_encoded == []:
            continue
        max_encoded_len = max([len(adj_encoded[i]) for i in range(len(adj_encoded))])
        max_prev_node.append(max_encoded_len)
    max_prev_node = sorted(max_prev_node)[-1 * topk:]
    return max_prev_node

def encode_adj_flexible(adj):
    '''
    return a flexible length of output
    note that here there is no loss when encoding/decoding an adj matrix
    :param adj: adj matrix
    :return:
    '''
    # pick up lower tri
    adj = np.tril(adj, k=-1)
    n = adj.shape[0]
    adj = adj[1:n, 0:n - 1]

    adj_output = []
    input_start = 0
    for i in range(adj.shape[0]):
        input_end = i + 1
        adj_slice = adj[i, input_start:input_end]
        adj_output.append(adj_slice)
        non_zero = np.nonzero(adj_slice)[0]
        input_start = input_end - len(adj_slice) + np.amin(non_zero)

    return adj_output

def bfs_seq(G, start_id):
    '''
    get a bfs node sequence
    :param G:
    :param start_id:
    :return:
    '''
    dictionary = dict(nx.bfs_successors(G, start_id))
    start = [start_id]
    output = [start_id]
    while len(start) > 0:
        next = []
        while len(start) > 0:
            current = start.pop(0)
            neighbor = dictionary.get(current)
            if neighbor is not None:
                #### a wrong example, should not permute here!
                # shuffle(neighbor)
                next = next + neighbor
        output = output + next
        start = next
    return output

# %% [markdown]
# ### Erdos Renyi graphs

# %%
max_prev_nodes=[]
p_parameters=np.arange(0.1,1,0.05)
random.seed(123)

for p in p_parameters:
    graphs=[]
    for i in range(100, 200):
        graphs.append(nx.erdos_renyi_graph(i, p))
    shuffle(graphs)
    dataset = Graph_to_sequence(graphs)
    m=dataset.max_prev_node
    max_prev_nodes.append(m)
# Out:
# calculating max previous node, total iteration: 20000
# iter 0 times
# iter 4000 times
# iter 8000 times
# iter 12000 times
# iter 16000 times
# max previous node: 170
# calculating max previous node, total iteration: 20000
# iter 0 times
# iter 4000 times
# iter 8000 times
# iter 12000 times
# iter 16000 times
# max previous node: 178
# calculating max previous node, total iteration: 20000
# iter 0 times
# iter 4000 times
# iter 8000 times
# iter 12000 times
# iter 16000 times
# max previous node: 183
# calculating max previous node, total iteration: 20000
# iter 0 times
# iter 4000 times
# iter 8000 times
# iter 12000 times
# iter 16000 times
# max previous node: 187
# calculating max previous node, total iteration: 20000
# iter 0 times
# iter 4000 times
# iter 8000 times
# iter 12000 times
# iter 16000 times
# max previous node: 189
# calculating max previous node, total iteration: 20000
# iter 0 times
# iter 4000 times
# iter 8000 times
# iter 12000 times
# iter 16000 times
# ...

# %%
plt.plot(p_parameters,max_prev_nodes)
plt.title("max_prev_nodes of erdos renyi graphs of parameters n=100 to 200 and p=p_parameter")
plt.xlabel("p_parameters")
plt.ylabel("max_prev_nodes")
plt.show()

# %%
max_prev_nodes=[]
p_parameters=np.arange(0.1,1,0.1)
random.seed(123)

for p in p_parameters:
    graphs=[]
    for i in range(100):
        graphs.append(nx.erdos_renyi_graph(np.random.randint(100,200), p))
    shuffle(graphs)
    dataset = Graph_to_sequence(graphs,iteration=1000)
    m=dataset.max_prev_node
    max_prev_nodes.append(m)
# Out:
# calculating max previous node, total iteration: 1000
# iter 0 times
# iter 200 times
# iter 400 times
# iter 600 times
# iter 800 times
# max previous node: 167
# calculating max previous node, total iteration: 1000
# iter 0 times
# iter 200 times
# iter 400 times
# iter 600 times
# iter 800 times
# max previous node: 181
# calculating max previous node, total iteration: 1000
# iter 0 times
# iter 200 times
# iter 400 times
# iter 600 times
# iter 800 times
# max previous node: 188
# calculating max previous node, total iteration: 1000
# iter 0 times
# iter 200 times
# iter 400 times
# iter 600 times
# iter 800 times
# max previous node: 189
# calculating max previous node, total iteration: 1000
# iter 0 times
# iter 200 times
# iter 400 times
# iter 600 times
# iter 800 times
# max previous node: 193
# calculating max previous node, total iteration: 1000
# iter 0 times
# iter 200 times
# iter 400 times
# iter 600 times
# iter 800 times
# max previous node: 194
# ...

# %%
plt.plot(p_parameters,max_prev_nodes)
plt.title("max_prev_nodes of erdos renyi graphs of parameters n=100 to 200 and p=p_parameter")
plt.xlabel("p_parameters")
plt.ylabel("max_prev_nodes")
plt.show()

# %%
max_prev_nodes=[]
p_parameters=np.arange(0.1,1,0.1)
random.seed(123)

for p in p_parameters:
    graphs=[]
    for i in range(100):
        graphs.append(nx.erdos_renyi_graph(np.random.randint(400,500), p))
    shuffle(graphs)
    dataset = Graph_to_sequence(graphs,iteration=1000)
    m=dataset.max_prev_node
    max_prev_nodes.append(m)
# Out:
# calculating max previous node, total iteration: 1000
# iter 0 times
# iter 200 times
# iter 400 times
# iter 600 times
# iter 800 times
# max previous node: 459
# calculating max previous node, total iteration: 1000
# iter 0 times
# iter 200 times
# iter 400 times
# iter 600 times
# iter 800 times
# max previous node: 478
# calculating max previous node, total iteration: 1000
# iter 0 times
# iter 200 times
# iter 400 times
# iter 600 times
# iter 800 times
# max previous node: 485
# calculating max previous node, total iteration: 1000
# iter 0 times
# iter 200 times
# iter 400 times
# iter 600 times
# iter 800 times
# max previous node: 490
# calculating max previous node, total iteration: 1000
# iter 0 times
# iter 200 times
# iter 400 times
# iter 600 times
# iter 800 times
# max previous node: 491
# calculating max previous node, total iteration: 1000
# iter 0 times
# iter 200 times
# iter 400 times
# iter 600 times
# iter 800 times
# max previous node: 493
# ...

# %%
plt.plot(p_parameters,max_prev_nodes)
plt.title("max_prev_nodes of erdos renyi graphs of parameters n=100 to 200 and p=p_parameter")
plt.xlabel("p_parameters")
plt.ylabel("max_prev_nodes")
plt.show()

# %% [markdown]
# ### Barabasi Albert graphs

# %%
max_prev_nodes=[]
m_parameters=np.arange(1,100,1)
random.seed(123)

for m in m_parameters:
    graphs=[]
    for i in range(150):
        graphs.append(nx.barabasi_albert_graph(random.randint(100,200),m))
    shuffle(graphs)
    dataset = Graph_to_sequence(graphs,iteration=1000)
    m=dataset.max_prev_node
    max_prev_nodes.append(m)
# Out:
# calculating max previous node, total iteration: 1000
# iter 0 times
# iter 200 times
# iter 400 times
# iter 600 times
# iter 800 times
# max previous node: 92
# calculating max previous node, total iteration: 1000
# iter 0 times
# iter 200 times
# iter 400 times
# iter 600 times
# iter 800 times
# max previous node: 124
# calculating max previous node, total iteration: 1000
# iter 0 times
# iter 200 times
# iter 400 times
# iter 600 times
# iter 800 times
# max previous node: 140
# calculating max previous node, total iteration: 1000
# iter 0 times
# iter 200 times
# iter 400 times
# iter 600 times
# iter 800 times
# max previous node: 150
# calculating max previous node, total iteration: 1000
# iter 0 times
# iter 200 times
# iter 400 times
# iter 600 times
# iter 800 times
# max previous node: 158
# calculating max previous node, total iteration: 1000
# iter 0 times
# iter 200 times
# iter 400 times
# iter 600 times
# iter 800 times
# max previous node: 164
# ...

# %%
plt.plot(m_parameters,max_prev_nodes)
plt.title("max_prev_nodes of barabasi graphs of parameters n=100 to 200 and pm=m_parameter")
plt.xlabel("m_parameter")
plt.ylabel("max_prev_nodes")
plt.show()

# %%
import pandas as pd
from collections import defaultdict
import pickle

# %%
stat_results_community_gran='exp/GRAN/GRANMixtureBernoulli_community_2021-Jul-12-23-47-21_15676/evaluation_stats.p'
stat_results_community_graphrnn='exp/GraphRNN/RNN_community_2021-Jul-14-12-23-13_3500/evaluation_stats.p'
stat_results_erdos_graphrnn='exp/GraphRNN/RNN_erdos_2021-Jul-08-20-06-24_18932/evaluation_stats.p'
stat_results_erdos_graphrnn_mlp='exp/GraphRNN/RNN_erdos_2021-Jul-11-10-47-28_8208/evaluation_stats.p'

# %%
stat_list=defaultdict(lambda :defaultdict(float))
def add_entry_table(stat_result,stat_list,name):
    train_data_file = open(stat_result, 'rb')
    db = pickle.load(train_data_file)
    stat_list[name]=db

# %%
add_entry_table(stat_results_community_gran,stat_list,'stat_results_community_gran')
add_entry_table(stat_results_community_graphrnn,stat_list,'stat_results_community_graphrnn')
add_entry_table(stat_results_erdos_graphrnn,stat_list,'stat_results_erdos_graphrnn')
add_entry_table(stat_results_erdos_graphrnn_mlp,stat_list,'stat_results_erdos_graphrnn_mlp')

# %%
df = pd.DataFrame(stat_list)
print(df)
# Out:
#                      stat_results_community_gran  \
# mmd_num_nodes_dev                       0.726366
# mmd_degree_dev                          0.007070
# mmd_clustering_dev                      0.074003
# mmd_4orbits_dev                         0.000000
# mmd_spectral_dev                        0.019330
# mmd_num_nodes_test                      0.726366
# mmd_degree_test                         0.006636
# mmd_clustering_test                     0.074612
# mmd_4orbits_test                        0.000000
# mmd_spectral_test                       0.020121
#
#                      stat_results_community_graphrnn  \
# mmd_num_nodes_dev                           2.000000
# mmd_degree_dev                              0.222256
# mmd_clustering_dev                          0.087587
# mmd_4orbits_dev                             0.000000
# mmd_spectral_dev                            0.105210
# mmd_num_nodes_test                          2.000000
# ...

# %%
def n_community(c_sizes, p_inter=0.01):
    graphs = [nx.gnp_random_graph(c_sizes[i], 0.7, seed=i) for i in range(len(c_sizes))]
    G = nx.disjoint_union_all(graphs)
    communities = list(nx.connected_component_subgraphs(G))
    for i in range(len(communities)):
        subG1 = communities[i]
        nodes1 = list(subG1.nodes())
        for j in range(i + 1, len(communities)):
            subG2 = communities[j]
            nodes2 = list(subG2.nodes())
            has_inter_edge = False
            for n1 in nodes1:
                for n2 in nodes2:
                    if np.random.rand() < p_inter:
                        G.add_edge(n1, n2)
                        has_inter_edge = True
            if not has_inter_edge:
                G.add_edge(nodes1[0], nodes2[0])
    # print('connected comp: ', len(list(nx.connected_component_subgraphs(G))))
    return G

# %%
c_sizes = [15] * 4
graph=n_community(c_sizes, p_inter=0.01)

# %%
def commpute_dfs_bfs(G):
    CGs = [G.subgraph(c) for c in nx.connected_components(G)]

    # rank connected componets from large to small size
    CGs = sorted(CGs, key=lambda x: x.number_of_nodes(), reverse=True)

    node_list_bfs = []
    node_list_dfs = []
    for ii in range(len(CGs)):
        node_degree_list = [(n, d) for n, d in CGs[ii].degree()]
        degree_sequence = sorted(
            node_degree_list, key=lambda tt: tt[1], reverse=True)

        bfs_tree = nx.bfs_tree(CGs[ii], source=degree_sequence[0][0])
        dfs_tree = nx.dfs_tree(CGs[ii], source=degree_sequence[0][0])

        node_list_bfs += list(bfs_tree.nodes())
        node_list_dfs += list(dfs_tree.nodes())
        adjbfs =nx.to_numpy_matrix(G, nodelist=node_list_bfs)
        adjdfs =nx.to_numpy_matrix(G, nodelist=node_list_dfs)

    return adjbfs , adjdfs

# %%
graph= nx.barabasi_albert_graph(500, 5)
adjbfs,adjdfs = commpute_dfs_bfs(graph)

# %%
plt.matshow(adjbfs);
plt.colorbar()
plt.show()

# %%
plt.matshow(adjdfs);
plt.colorbar()
plt.show()

# %%
n = 250
tau1 = 3
tau2 = 1.5
mu = 0.1
G = LFR_benchmark_graph(n, tau1=3, tau2=1.5, mu=0.1, average_degree=5, min_community=20, seed=10)

# %%
adjbfs,adjdfs = commpute_dfs_bfs(G)

# %%
plt.matshow(adjbfs);
plt.colorbar()
plt.show()

# %%
plt.matshow(adjdfs);
plt.colorbar()
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
graph = nx.watts_strogatz_graph(15,4,0)
nx.draw_circular(graph)

# %%
graph = nx.watts_strogatz_graph(15,4,0.3)
nx.draw_circular(graph)

# %%
graph = nx.watts_strogatz_graph(15,4,1)
nx.draw_circular(graph)
