# %%
import powerlaw
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

# %%
graphs=[]
for i in range(100,200):
    for k in range(5):
        graphs.append(nx.barabasi_albert_graph(i,4))

# %%
mean_fit = np.mean([powerlaw.Fit(sorted([d for n, d in graph.degree()], reverse=True)).alpha for graph in graphs])
# Out:
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# ...

# %%
avg_path_length = np.mean([nx.average_shortest_path_length(g) for g in graphs])

# %%
#
G = nx.barabasi_albert_graph(1000, 5)
degree_freq = nx.degree_histogram(G)
degrees = range(len(degree_freq))
plt.figure(figsize=(12, 8))
plt.loglog(degrees[m:], degree_freq[m:],'go')
plt.xlabel('Degree')
plt.ylabel('Frequency')
plt.savefig('degree_hist_BA.png')

# %%
def plot_degree_dist(G):
    degrees = [G.degree(n) for n in G.nodes()]
    plt.hist(degrees)
    plt.show()

plot_degree_dist(G = nx.barabasi_albert_graph(1000, m))

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('exp/GRAN/grid/GRANMixtureBernoulli_grid_2021-Sep-18-19-09-09_16816/stat_across_epochs.csv')

# %%
df[['epoch_num','mmd_degree_test']]
# Out:
#      epoch_num  mmd_degree_test
# 0            5         0.338862
# 1           10         0.454046
# 2           15         0.485864
# 3           20         0.343517
# 4           25         0.343827
# ..         ...              ...
# 595       2980         0.000703
# 596       2985         0.004903
# 597       2990         0.000899
# 598       2995         0.000394
# 599       3000         0.001251
#
# [600 rows x 2 columns]

# %%
plt.figure()

x = df['epoch_num']
y1 = df['mmd_degree_test']
plt.figure(figsize=(12, 8))
plt.xlabel('Epochs')
plt.ylabel('MMD_Degree_Test')
plt.plot(x,y1)
plt.yscale("log")
plt.savefig('mmd_epochs_degree_grid_gran.png')
# Out:
# D:\anaconda3\envs\graphRL\lib\site-packages\matplotlib\cbook\__init__.py:2064: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# D:\anaconda3\envs\graphRL\lib\site-packages\matplotlib\axes\_base.py:248: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# D:\anaconda3\envs\graphRL\lib\site-packages\matplotlib\axes\_base.py:250: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
